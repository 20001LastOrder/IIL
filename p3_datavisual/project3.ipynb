# %% [markdown]
# ### Borrow count history for each university

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.cbook as cbook

# %%
borrowhistory = pd.read_csv('borrow.csv')

# %%
print((borrowhistory))
# Out:
#     borrowcount                                      iname
# 0             5                Southern Schuster Institute
# 1             5                    Western Yukon Institute
# 2            14                          Corwin University
# 3            15    Eastern Prince Edward Island University
# 4             7                            Pollich College
# 5            12              Eastern Runolfsdottir College
# 6            12                          Bednar University
# 7            10                         East Boehm Academy
# 8            12                               West Keebler
# 9            10                Northern Streich University
# 10            8                     The Vandervort Academy
# 11            2                             Larkin College
# 12            7                             Haag Institute
# 13           10                         East Yukon College
# 14           10                       East Krajcik Academy
# ...

# %%
plt.figure(figsize=(15, 15))
x = np.arange(len(np.array(borrowhistory['iname'])))
plt.bar(x, np.array(borrowhistory['borrowcount']))

plt.xticks(x, np.array(borrowhistory['iname']), rotation='vertical')
plt.xlabel('uni name')
plt.ylabel('borrow count ')
plt.show()

# %%
libraryrecord = pd.read_csv('library.csv')

# %%
print(libraryrecord)
# Out:
#     libraryCount                                    iname
# 0              3                   South Quebec Institute
# 1              2                              West Legros
# 2              2                  North Ontario Institute
# 3              4                  Southern Senger College
# 4              2                            Eastern Brown
# 5              3  Eastern Prince Edward Island University
# 6              3                          Pollich College
# 7              4                  Western Yukon Institute
# 8              3                  South Ontario Institute
# 9              4                     North Quebec College
# 10             2                   The Vandervort Academy
# 11             2                        Bednar University
# 12             2                       East Boehm Academy
# 13             3                        Bailey University
# 14             4                             The Parisian
# ...

# %%
plt.figure(figsize=(15, 15))
x = np.arange(len(np.array(libraryrecord['iname'])))
plt.bar(x, np.array(libraryrecord['libraryCount']))
plt.xticks(x, np.array(libraryrecord['iname']), rotation='vertical')
plt.xlabel('uni name')
plt.ylabel('number of librarys')
plt.show()
